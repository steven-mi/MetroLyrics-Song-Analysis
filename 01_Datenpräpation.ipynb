# %% [markdown]
# # Datenpräparation

# %% [markdown]
# 1. Einlesen der CSV-Datei
# 2. Entfernen der NaN-Einträge
# 3. Aufteilen des zusammenhängenden Textes in einzelne Wörter
# 4. Entfernen aller Satzzeichen
# 5. Abgrenzen des Zeitraums 1970 bis 2016
# 6. Hinzufügen einer Wörterzahl Eigenschaft
# 7. Texte zwischen 15 und 1500 Wörter
# 8. Speichern einer präparierten CSV-Datei

# %%
import pandas as pd

# %% [markdown]
# ### Einlesen der CSV-Datei

# %%
df = pd.read_csv('lyrics.csv')
df.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                                 text
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...

# %% [markdown]
# ## Formatierung der Buchstaben
# Alle Buchstaben werden in ihere kleingeschriebene Form gebracht

# %%
df['text'] = df['text'].str.lower()
df.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                                 text
# 0  oh baby, how you doing?\nyou know i'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  if you search\nfor tenderness\nit isn't hard t...
# 3  oh oh oh i, oh oh oh i\n[verse 1:]\nif i wrote...
# 4  party the people, the people the party it's po...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362237 entries, 0 to 362236
# Data columns (total 6 columns):
# index     362237 non-null int64
# song      362235 non-null object
# year      362237 non-null int64
# artist    362237 non-null object
# genre     362237 non-null object
# text      266557 non-null object
# dtypes: int64(2), object(4)
# memory usage: 16.6+ MB

# %% [markdown]
# ### Entfernen der NaN-Einträge

# %%
df = df.fillna("")

# %% [markdown]
# ### Aufteilen des zusammenhängenden Textes in einzelne Wörter
# Aus der Bibliothek nltk.tokenize nutzen wir die Funktion word_tokenize um die einzelnen Wörter zu separieren

# %%
from nltk.tokenize import word_tokenize
df['word_tokenize'] = df['text'].apply(word_tokenize)

# %% [markdown]
# ### Entfernen aller Satzzeichen
# Wir entfernen semtliche Interpunktionen aus unserem Datensatz

# %%
import string
stop = list(string.punctuation)

df['word_tokenize_no_punctuation'] = df['word_tokenize'].apply(lambda x: [item for item in x if item not in stop])
df['word_tokenize_no_punctuation']
# Out:
# 0         [oh, baby, how, you, doing, you, know, i, 'm, ...
# 1         [playin, everything, so, easy, it, 's, like, y...
# 2         [if, you, search, for, tenderness, it, is, n't...
# 3         [oh, oh, oh, i, oh, oh, oh, i, verse, 1, if, i...
# 4         [party, the, people, the, people, the, party, ...
# 5         [i, heard, church, bells, ringing, i, heard, a...
# 6         [this, is, just, another, day, that, i, would,...
# 7         [waiting, waiting, waiting, waiting, waiting, ...
# 8         [verse, 1, i, read, all, of, the, magazines, w...
# 9         [n-n-now, honey, you, better, sit, down, and, ...
# 10        [i, lay, alone, awake, at, night, sorrow, fill...
# 11        [hello, hello, baby, you, called, i, ca, n't, ...
# 12        [feels, like, i, 'm, losing, my, mind, love, i...
# 13        [youre, everything, i, thought, you, never, we...
# 14        [i, got, ta, give, up, to, quite, the, storm, ...
# 15        [it, really, hurts, to, say, this, yes, it, do...
# 16        [you, 're, bad, for, me, i, clearly, get, it, ...
# 17        [chorus, i, 'm, a, world, wide, woman, www, yo...
# 18        [ay, ay, ay, nobody, likes, to, be, played, oh...
# 19        [ay, ay, nobody, likes, being, played, ay, oh,...
# 20        [ay, ay, nobody, likes, being, played, ay, oh,...
# 21        [beyonc, intro, beyonce, iam, welcome, welcome...
# 22        [ay, ay, nobody, likes, being, played, ay, oh,...
# 23        [took, me, a, while, but, i, 'm, finally, here...
# 24        [ay, ay, ay, oh, beyonc, beyonc, oh, beyonc, b...
# 25        [to, the, left, to, the, left, to, the, left, ...
# 26        [remember, the, first, day, when, i, saw, your...
# 27        [you, say, that, he, 's, wrong, you, say, that...
# 28        [1st, verse, hey, you, what, 's, the, deal, it...
# 29        [he, is, always, laughin, and, flirting, with,...
#                                 ...
# 362207                                                   []
# 362208    [we, are, everyday, robots, on, our, phones, i...
# 362209    [when, your, soul, is, n't, right, and, it, 's...
# 362210    [when, the, photographs, you, 're, taking, now...
# 362211    [i, met, moko, jumbie, he, walks, on, stilts, ...
# 362212    [chill, on, the, hollow, ponds, set, sail, by,...
# 362213    [celebrate, the, passing, drugs, put, them, on...
# 362214    [when, the, serve, is, done, and, the, parish,...
# 362215                                                   []
# 362216                                                   []
# 362217                                                   []
# 362218                                                   []
# 362219                 [trilo, hã¤r, ã¤r, han, nã¤ra, land]
# 362220                                                   []
# 362221                                                   []
# 362222                                                   []
# 362223                                                   []
# 362224                                                   []
# 362225    [days, getting, dark, and, the, nights, are, g...
# 362226    [you, 'll, never, know, my, name, and, my, pic...
# 362227    [you, walked, in, shining, brighter, than, a, ...
# 362228    [i, warned, you, that, the, tank, was, low, sh...
# 362229    [to, my, first, pony, cherry, pie, from, the, ...
# 362230    [it, was, two, years, ago, and, it, was, yeste...
# 362231    [you, 've, got, your, texas, way, of, walking,...
# 362232    [i, got, ta, say, boy, after, only, just, a, c...
# 362233    [i, helped, you, find, her, diamond, ring, you...
# 362234    [look, at, the, couple, in, the, corner, booth...
# 362235    [when, i, fly, off, this, mortal, earth, and, ...
# 362236    [i, heard, from, a, friend, of, a, friend, of,...
# Name: word_tokenize_no_punctuation, Length: 362237, dtype: object

# %% [markdown]
# ### Abgrenzen des Zeitraums
# Zeitraum von 1970 bis 2016

# %%
df = df[df['year'] >= 1970]
df = df[df['year'] <= 2016]
df
# Out:
#          index                                               song  year  \
# 0            0                                          ego-remix  2009
# 1            1                                       then-tell-me  2009
# 2            2                                            honesty  2009
# 3            3                                    you-are-my-rock  2009
# 4            4                                      black-culture  2009
# 5            5                             all-i-could-do-was-cry  2009
# 6            6                                 once-in-a-lifetime  2009
# 7            7                                            waiting  2009
# 8            8                                          slow-love  2009
# 9            9                              why-don-t-you-love-me  2009
# 10          10                                      save-the-hero  2009
# 11          11                                          telephone  2009
# 12          12                                    ice-cream-truck  2009
# 13          13                             no-broken-hearted-girl  2009
# 14          14                                            control  2009
# 15          15                                      i-m-alone-now  2009
# 16          16                                             poison  2009
# 17          17                                   world-wide-women  2007
# 18          18                                     beautiful-liar  2007
# 19          19                             beautiful-liar-spanish  2007
# 20          20                   beautiful-liar-spanglish-version  2007
# 21          21                                          bienvenue  2007
# 22          22                                beutiful-liar-remix  2007
# 23          23  he-still-loves-me-f-choir-from-fighting-tempta...  2007
# 24          24                                    bello-embustero  2007
# 25          25                                         irreplable  2007
# 26          26                                      the-first-day  2007
# 27          27                                             my-man  2007
# 28          28                                 what-s-it-gonna-be  2007
# 29          29                                                 if  2007
# ...        ...                                                ...   ...
# 362207  362207                                           parakeet  2014
# 362208  362208                                    everyday-robots  2014
# 362209  362209                                 heavy-seas-of-love  2014
# 362210  362210                     photographs-you-are-taking-now  2014
# 362211  362211                                         you-and-me  2014
# 362212  362212                                       hollow-ponds  2014
# 362213  362213                                  the-selfish-giant  2014
# 362214  362214                                           hostiles  2014
# 362215  362215                            polska-efter-roligs-per  2015
# 362216  362216                                         gullharpan  2015
# 362217  362217                                     kom-helge-ande  2015
# 362218  362218                            polska-efter-jones-olle  2015
# 362219  362219                                              trilo  2015
# 362220  362220                                       knut-hauling  2015
# 362221  362221                                            jemsken  2015
# 362222  362222                 tacker-herranom-mats-hansu-polskan  2015
# 362223  362223                                           mannelig  2015
# 362224  362224                                           vallsvit  2015
# 362225  362225              can-t-you-see-that-you-are-killing-me  2015
# 362226  362226                          you-ll-never-know-my-name  2015
# 362227  362227                                too-good-to-be-true  2012
# 362228  362228                                      skinny-dippin  2012
# 362229  362229                                         cherry-pie  2012
# 362230  362230                                      feels-so-real  2012
# 362231  362231                                       swingin-door  2012
# 362232  362232                          who-am-i-drinking-tonight  2012
# 362233  362233                                               liar  2012
# 362234  362234                                        last-supper  2012
# 362235  362235                        christ-alone-live-in-studio  2012
# 362236  362236                                               amen  2012
#
#                  artist    genre  \
# 0       beyonce-knowles      Pop
# 1       beyonce-knowles      Pop
# 2       beyonce-knowles      Pop
# 3       beyonce-knowles      Pop
# 4       beyonce-knowles      Pop
# 5       beyonce-knowles      Pop
# 6       beyonce-knowles      Pop
# 7       beyonce-knowles      Pop
# 8       beyonce-knowles      Pop
# 9       beyonce-knowles      Pop
# 10      beyonce-knowles      Pop
# 11      beyonce-knowles      Pop
# 12      beyonce-knowles      Pop
# 13      beyonce-knowles      Pop
# 14      beyonce-knowles      Pop
# 15      beyonce-knowles      Pop
# 16      beyonce-knowles      Pop
# 17      beyonce-knowles      Pop
# 18      beyonce-knowles      Pop
# 19      beyonce-knowles      Pop
# 20      beyonce-knowles      Pop
# 21      beyonce-knowles      Pop
# 22      beyonce-knowles      Pop
# 23      beyonce-knowles      Pop
# 24      beyonce-knowles      Pop
# 25      beyonce-knowles      Pop
# 26      beyonce-knowles      Pop
# 27      beyonce-knowles      Pop
# 28      beyonce-knowles      Pop
# 29      beyonce-knowles      Pop
# ...                 ...      ...
# 362207     damon-albarn      Pop
# 362208     damon-albarn      Pop
# 362209     damon-albarn      Pop
# 362210     damon-albarn      Pop
# 362211     damon-albarn      Pop
# 362212     damon-albarn      Pop
# 362213     damon-albarn      Pop
# 362214     damon-albarn      Pop
# 362215     ale-mrthller    Other
# 362216     ale-mrthller    Other
# 362217     ale-mrthller    Other
# 362218     ale-mrthller    Other
# 362219     ale-mrthller    Other
# 362220     ale-mrthller    Other
# 362221     ale-mrthller    Other
# 362222     ale-mrthller    Other
# 362223     ale-mrthller    Other
# 362224     ale-mrthller    Other
# 362225         dee-smgn    Other
# 362226         dee-smgn    Other
# 362227       edens-edge  Country
# 362228       edens-edge  Country
# 362229       edens-edge  Country
# 362230       edens-edge  Country
# 362231       edens-edge  Country
# 362232       edens-edge  Country
# 362233       edens-edge  Country
# 362234       edens-edge  Country
# 362235       edens-edge  Country
# 362236       edens-edge  Country
#
#                                                      text  \
# 0       oh baby, how you doing?\nyou know i'm gonna cu...
# 1       playin' everything so easy,\nit's like you see...
# 2       if you search\nfor tenderness\nit isn't hard t...
# 3       oh oh oh i, oh oh oh i\n[verse 1:]\nif i wrote...
# 4       party the people, the people the party it's po...
# 5       i heard\nchurch bells ringing\ni heard\na choi...
# 6       this is just another day that i would spend\nw...
# 7       waiting, waiting, waiting, waiting\nwaiting, w...
# 8       [verse 1:]\ni read all of the magazines\nwhile...
# 9       n-n-now, honey\nyou better sit down and look a...
# 10      i lay alone awake at night\nsorrow fills my ey...
# 11      hello hello baby you called\ni can't hear a th...
# 12      feels like i'm losing my mind\nlove is so hard...
# 13      youre everything i thought you never were\nand...
# 14      i gotta give up\nto quite the storm that rages...
# 15      it really hurts to say this yes it does\nbut a...
# 16      you're bad for me i clearly get it\ni don't se...
# 17      [chorus:]\ni'm a world wide woman www you can ...
# 18      ay\nay\nay (nobody likes to be played)\noh, be...
# 19      ay! ay!\n(nobody likes being played)\nay!\noh!...
# 20      ay! ay!\n(nobody likes being played)\nay!\noh!...
# 21      beyonc - intro:\nbeyonce\niam\nwelcome\nwelcom...
# 22      ay! ay!\n(nobody likes being played)\nay!\noh!...
# 23      took me a while but i'm finally here\nso i jus...
# 24      ay! ay! ay!\noh! beyonc, beyonc\noh! beyonc, b...
# 25      to the left, to the left\nto the left, to the ...
# 26      remember the first day when i saw your face\nr...
# 27      you say that he's wrong\nyou say that he's no ...
# 28      1st verse:\nhey you what's the deal, its poppi...
# 29      he is always laughin' and flirting with me\nan...
# ...                                                   ...
# 362207
# 362208  we are everyday robots on our phones\nin the p...
# 362209  when your soul isn't right\nand it's raw to th...
# 362210  when the photographs you're taking now\nare ta...
# 362211  i met moko jumbie,\nhe walks on stilts through...
# 362212  chill on the hollow ponds\nset sail by a kid\n...
# 362213  celebrate the passing drugs\nput them on the b...
# 362214  when the serve is done\nand the parish shuffle...
# 362215
# 362216
# 362217
# 362218
# 362219                 trilo!\nhã¤r ã¤r han.\nnã¤ra land.
# 362220
# 362221
# 362222
# 362223
# 362224
# 362225  days getting dark and the nights are growing c...
# 362226  you'll never know my name\nand my pictures wil...
# 362227  you walked in shining brighter than a headligh...
# 362228  i warned you that the tank was low\nshoulda st...
# 362229  to my first pony, cherry pie\nfrom the little ...
# 362230  it was two years ago and it was yesterday\nit ...
# 362231  you've got your texas way of walking,\nyou've ...
# 362232  i gotta say\nboy, after only just a couple of ...
# 362233  i helped you find her diamond ring\nyou made m...
# 362234  look at the couple in the corner booth\nlooks ...
# 362235  when i fly off this mortal earth\nand i'm meas...
# 362236  i heard from a friend of a friend of a friend ...
#
#                                             word_tokenize  \
# 0       [oh, baby, ,, how, you, doing, ?, you, know, i...
# 1       [playin, ', everything, so, easy, ,, it, 's, l...
# 2       [if, you, search, for, tenderness, it, is, n't...
# 3       [oh, oh, oh, i, ,, oh, oh, oh, i, [, verse, 1,...
# 4       [party, the, people, ,, the, people, the, part...
# 5       [i, heard, church, bells, ringing, i, heard, a...
# 6       [this, is, just, another, day, that, i, would,...
# 7       [waiting, ,, waiting, ,, waiting, ,, waiting, ...
# 8       [[, verse, 1, :, ], i, read, all, of, the, mag...
# 9       [n-n-now, ,, honey, you, better, sit, down, an...
# 10      [i, lay, alone, awake, at, night, sorrow, fill...
# 11      [hello, hello, baby, you, called, i, ca, n't, ...
# 12      [feels, like, i, 'm, losing, my, mind, love, i...
# 13      [youre, everything, i, thought, you, never, we...
# 14      [i, got, ta, give, up, to, quite, the, storm, ...
# 15      [it, really, hurts, to, say, this, yes, it, do...
# 16      [you, 're, bad, for, me, i, clearly, get, it, ...
# 17      [[, chorus, :, ], i, 'm, a, world, wide, woman...
# 18      [ay, ay, ay, (, nobody, likes, to, be, played,...
# 19      [ay, !, ay, !, (, nobody, likes, being, played...
# 20      [ay, !, ay, !, (, nobody, likes, being, played...
# 21      [beyonc, -, intro, :, beyonce, iam, welcome, w...
# 22      [ay, !, ay, !, (, nobody, likes, being, played...
# 23      [took, me, a, while, but, i, 'm, finally, here...
# 24      [ay, !, ay, !, ay, !, oh, !, beyonc, ,, beyonc...
# 25      [to, the, left, ,, to, the, left, to, the, lef...
# 26      [remember, the, first, day, when, i, saw, your...
# 27      [you, say, that, he, 's, wrong, you, say, that...
# 28      [1st, verse, :, hey, you, what, 's, the, deal,...
# 29      [he, is, always, laughin, ', and, flirting, wi...
# ...                                                   ...
# 362207                                                 []
# 362208  [we, are, everyday, robots, on, our, phones, i...
# 362209  [when, your, soul, is, n't, right, and, it, 's...
# 362210  [when, the, photographs, you, 're, taking, now...
# 362211  [i, met, moko, jumbie, ,, he, walks, on, stilt...
# 362212  [chill, on, the, hollow, ponds, set, sail, by,...
# 362213  [celebrate, the, passing, drugs, put, them, on...
# 362214  [when, the, serve, is, done, and, the, parish,...
# 362215                                                 []
# 362216                                                 []
# 362217                                                 []
# 362218                                                 []
# 362219      [trilo, !, hã¤r, ã¤r, han, ., nã¤ra, land, .]
# 362220                                                 []
# 362221                                                 []
# 362222                                                 []
# 362223                                                 []
# 362224                                                 []
# 362225  [days, getting, dark, and, the, nights, are, g...
# 362226  [you, 'll, never, know, my, name, and, my, pic...
# 362227  [you, walked, in, shining, brighter, than, a, ...
# 362228  [i, warned, you, that, the, tank, was, low, sh...
# 362229  [to, my, first, pony, ,, cherry, pie, from, th...
# 362230  [it, was, two, years, ago, and, it, was, yeste...
# 362231  [you, 've, got, your, texas, way, of, walking,...
# 362232  [i, got, ta, say, boy, ,, after, only, just, a...
# 362233  [i, helped, you, find, her, diamond, ring, you...
# 362234  [look, at, the, couple, in, the, corner, booth...
# 362235  [when, i, fly, off, this, mortal, earth, and, ...
# 362236  [i, heard, from, a, friend, of, a, friend, of,...
#
#                              word_tokenize_no_punctuation
# 0       [oh, baby, how, you, doing, you, know, i, 'm, ...
# 1       [playin, everything, so, easy, it, 's, like, y...
# 2       [if, you, search, for, tenderness, it, is, n't...
# 3       [oh, oh, oh, i, oh, oh, oh, i, verse, 1, if, i...
# 4       [party, the, people, the, people, the, party, ...
# 5       [i, heard, church, bells, ringing, i, heard, a...
# 6       [this, is, just, another, day, that, i, would,...
# 7       [waiting, waiting, waiting, waiting, waiting, ...
# 8       [verse, 1, i, read, all, of, the, magazines, w...
# 9       [n-n-now, honey, you, better, sit, down, and, ...
# 10      [i, lay, alone, awake, at, night, sorrow, fill...
# 11      [hello, hello, baby, you, called, i, ca, n't, ...
# 12      [feels, like, i, 'm, losing, my, mind, love, i...
# 13      [youre, everything, i, thought, you, never, we...
# 14      [i, got, ta, give, up, to, quite, the, storm, ...
# 15      [it, really, hurts, to, say, this, yes, it, do...
# 16      [you, 're, bad, for, me, i, clearly, get, it, ...
# 17      [chorus, i, 'm, a, world, wide, woman, www, yo...
# 18      [ay, ay, ay, nobody, likes, to, be, played, oh...
# 19      [ay, ay, nobody, likes, being, played, ay, oh,...
# 20      [ay, ay, nobody, likes, being, played, ay, oh,...
# 21      [beyonc, intro, beyonce, iam, welcome, welcome...
# 22      [ay, ay, nobody, likes, being, played, ay, oh,...
# 23      [took, me, a, while, but, i, 'm, finally, here...
# 24      [ay, ay, ay, oh, beyonc, beyonc, oh, beyonc, b...
# 25      [to, the, left, to, the, left, to, the, left, ...
# 26      [remember, the, first, day, when, i, saw, your...
# 27      [you, say, that, he, 's, wrong, you, say, that...
# 28      [1st, verse, hey, you, what, 's, the, deal, it...
# 29      [he, is, always, laughin, and, flirting, with,...
# ...                                                   ...
# 362207                                                 []
# 362208  [we, are, everyday, robots, on, our, phones, i...
# 362209  [when, your, soul, is, n't, right, and, it, 's...
# 362210  [when, the, photographs, you, 're, taking, now...
# 362211  [i, met, moko, jumbie, he, walks, on, stilts, ...
# 362212  [chill, on, the, hollow, ponds, set, sail, by,...
# 362213  [celebrate, the, passing, drugs, put, them, on...
# 362214  [when, the, serve, is, done, and, the, parish,...
# 362215                                                 []
# 362216                                                 []
# 362217                                                 []
# 362218                                                 []
# 362219               [trilo, hã¤r, ã¤r, han, nã¤ra, land]
# 362220                                                 []
# 362221                                                 []
# 362222                                                 []
# 362223                                                 []
# 362224                                                 []
# 362225  [days, getting, dark, and, the, nights, are, g...
# 362226  [you, 'll, never, know, my, name, and, my, pic...
# 362227  [you, walked, in, shining, brighter, than, a, ...
# 362228  [i, warned, you, that, the, tank, was, low, sh...
# 362229  [to, my, first, pony, cherry, pie, from, the, ...
# 362230  [it, was, two, years, ago, and, it, was, yeste...
# 362231  [you, 've, got, your, texas, way, of, walking,...
# 362232  [i, got, ta, say, boy, after, only, just, a, c...
# 362233  [i, helped, you, find, her, diamond, ring, you...
# 362234  [look, at, the, couple, in, the, corner, booth...
# 362235  [when, i, fly, off, this, mortal, earth, and, ...
# 362236  [i, heard, from, a, friend, of, a, friend, of,...
#
# [362220 rows x 8 columns]

# %% [markdown]
# ### Wörter der Lieder zählen
# Als Eigenschaft speichern

# %%
df['word_tokenize_length'] = df['word_tokenize_no_punctuation'].apply(len)

# %% [markdown]
# ###  Wortzahl eingrenzen
# Texte zwischen 15 und 1500 Wörter

# %%
df = df[df['word_tokenize_length'] >= 15]
df = df[df['word_tokenize_length'] <= 1500]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259793 entries, 0 to 362236
# Data columns (total 9 columns):
# index                           259793 non-null int64
# song                            259793 non-null object
# year                            259793 non-null int64
# artist                          259793 non-null object
# genre                           259793 non-null object
# text                            259793 non-null object
# word_tokenize                   259793 non-null object
# word_tokenize_no_punctuation    259793 non-null object
# word_tokenize_length            259793 non-null int64
# dtypes: int64(3), object(6)
# memory usage: 19.8+ MB

# %%
df.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                                 text  \
# 0  oh baby, how you doing?\nyou know i'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  if you search\nfor tenderness\nit isn't hard t...
# 3  oh oh oh i, oh oh oh i\n[verse 1:]\nif i wrote...
# 4  party the people, the people the party it's po...
#
#                                        word_tokenize  \
# 0  [oh, baby, ,, how, you, doing, ?, you, know, i...
# 1  [playin, ', everything, so, easy, ,, it, 's, l...
# 2  [if, you, search, for, tenderness, it, is, n't...
# 3  [oh, oh, oh, i, ,, oh, oh, oh, i, [, verse, 1,...
# 4  [party, the, people, ,, the, people, the, part...
#
#                         word_tokenize_no_punctuation  word_tokenize_length
# 0  [oh, baby, how, you, doing, you, know, i, 'm, ...                   474
# 1  [playin, everything, so, easy, it, 's, like, y...                   270
# 2  [if, you, search, for, tenderness, it, is, n't...                   177
# 3  [oh, oh, oh, i, oh, oh, oh, i, verse, 1, if, i...                   555
# 4  [party, the, people, the, people, the, party, ...                   338

# %% [markdown]
# ## Stopwörter entfernen
# Festlegen der zu entfernenden Wörter

# %%
from nltk.corpus import stopwords
stop = list(stopwords.words('english'))
[words.capitalize() for words in stop]
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# Entfernen der festgelegten Wörter

# %%
df['word_tokenize_no_stopwords']=df['word_tokenize_no_punctuation'].apply(lambda x: [item for item in x if item not in stop])
df.head()
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                                 text  \
# 0  oh baby, how you doing?\nyou know i'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  if you search\nfor tenderness\nit isn't hard t...
# 3  oh oh oh i, oh oh oh i\n[verse 1:]\nif i wrote...
# 4  party the people, the people the party it's po...
#
#                                        word_tokenize  \
# 0  [oh, baby, ,, how, you, doing, ?, you, know, i...
# 1  [playin, ', everything, so, easy, ,, it, 's, l...
# 2  [if, you, search, for, tenderness, it, is, n't...
# 3  [oh, oh, oh, i, ,, oh, oh, oh, i, [, verse, 1,...
# 4  [party, the, people, ,, the, people, the, part...
#
#                         word_tokenize_no_punctuation  word_tokenize_length  \
# 0  [oh, baby, how, you, doing, you, know, i, 'm, ...                   474
# 1  [playin, everything, so, easy, it, 's, like, y...                   270
# 2  [if, you, search, for, tenderness, it, is, n't...                   177
# 3  [oh, oh, oh, i, oh, oh, oh, i, verse, 1, if, i...                   555
# 4  [party, the, people, the, people, the, party, ...                   338
#
#                           word_tokenize_no_stopwords
# 0  [oh, baby, know, 'm, gon, na, cut, right, chas...
# 1  [playin, everything, easy, 's, like, seem, sur...
# 2  [search, tenderness, n't, hard, find, love, ne...
# 3  [oh, oh, oh, oh, oh, oh, verse, 1, wrote, book...
# 4  [party, people, people, party, 's, popping, si...

# %% [markdown]
# ### Speichern einer präparierten CSV-Datei

# %%
#df[['song','year','genre','word_tokenize_no_punctuation','word_tokenize_length','word_tokenize_no_stopwords']].to_csv("lyrics_clean_utf8.csv",encoding='utf-8' )
